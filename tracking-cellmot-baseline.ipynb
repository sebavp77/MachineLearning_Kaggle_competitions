# %% [markdown]
# # This notebook will run the baseline model provided by the competition. It can be found in the official git repository: https://github.com/royerlab/kaggle-cell-tracking-competition/tree/main

# %% [markdown]
# # Clonning repository

# %%
# # Clonning Git repository
# !git clone https://github.com/royerlab/kaggle-cell-tracking-competition.git
# %cd kaggle-cell-tracking-competition

# %%
# !ls #Elements in the git repository

# %%
# # -------------------------- Installing necessary dependencies (in case they are not installed) ----------------------------
# import importlib
# import subprocess, sys
# packages = [
#     "torch",
#     "zarr",
#     "polars",
#     "scipy",
#     "napari",
#     "tracksdata"
# ]
# for pkg in packages:
#     try:
#         module = importlib.import_module(pkg)
#         version = getattr(module, "__version__", "Unknown")
#         print(f"Already:  {pkg:<12} {version}")
#     except ImportError:
#         print(f" {pkg:<12} NOT INSTALLED")
#         print(f"Installing package: {pkg}:")
#         try:
#             subprocess.check_call([sys.executable, "-m", "pip", "install", pkg])
#             print(f"---- -- Package {pkg} successfully installed ------ --")
#         except ImportError:
#             print(f"---- --Package {pkg} was NOT installed ------ --")

# %% [markdown]
# # Defining input data

# %%
from pathlib import Path
import os

# %%
from pathlib import Path
import os
data_path = Path('/kaggle/input/competitions/biohub-cell-tracking-during-development')
training_path =  data_path/'train'
test_path = data_path/'test'

#------------ Listing folders in train -----------
print("Input contents:", os.listdir(training_path)[:5],"\n")
print(" First 5 elements in train folder, it contains '.geff' folders (annotated graphs) and '.zarr' folder (videos)")
# Out:
# Input contents: ['6bba_2540cd90.geff', '44b6_0b24845f.geff', '44b6_996155de.geff', '44b6_0c582fdc.geff', '6bba_cf35214c.zarr']
#
#  First 5 elements in train folder, it contains '.geff' folders (annotated graphs) and '.zarr' folder (videos)

# %% [markdown]
# # Making a prediction with the baseline model

# %% [markdown]
# The notebook used to run the baseline can be found here: https://www.kaggle.com/code/thibautgoldsborough/unet-baseline-inference-submission

# %% [markdown]
# ## Configuration

# %%
COMP_DIR = data_path
TEST_DIR = test_path

ARTIFACTS = "/kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts"

REPO_DIR = "/kaggle/working/repo"
METHOD = "unet_transformer"

# --- Test-time options (tune these) ---------------------------------------
# Model checkpoint (relative to the repo, or an absolute path to your own).
WEIGHTS = f"weights/{METHOD}/split_0/edge_predictor_best.pth"

# GT: Ground-Truth
# Detection peak threshold. GT is sparse so the detector is poorly calibrated;
# 0.5 is too low, ~0.99 scored best in a sweep.
DET_THRESHOLD = 0.99

UNET_BATCH_SIZE = 4          # frame-pairs per UNet forward; lower if you OOM
SLICE = ":4"                   # e.g. ":5" to predict only the first 5 videos; "" = all

# Linking. ILP = global, flow-consistent (cleaner tracks; ~0.73->0.79).
# Set False for the faster greedy linker.
USE_ILP = True
ILP_EDGE_WEIGHT = -1.0           # weight on edge probability
ILP_APPEARANCE_WEIGHT = 0.1      # cost of a track appearing
ILP_DISAPPEARANCE_WEIGHT = 0.1   # cost of a track disappearing
ILP_DIVISION_WEIGHT = 1.0        # cost of a division; lower (~0.2) allows more splits
# --------------------------------------------------------------------------

# %% [markdown]
# ## Offline install & setup
# Install the dependencies from the bundled wheels (no internet), then copy the repo source and weights into a writable location and put the package on the import path

# %%
import glob
import os
import subprocess
import sys
import shutil

# 1. Find all wheels, but filter OUT numpy wheels to avoid breaking C-extensions
wheels = [
    f for f in glob.glob(f"{ARTIFACTS}/wheels/*.whl")
    if "numpy" not in os.path.basename(f).lower()
]

# 2. Install only the required non-NumPy wheels without upgrading dependencies
subprocess.run(
    [
        "pip", "install", 
        "--no-index", 
        "--find-links", f"{ARTIFACTS}/wheels",
        "--no-deps",
        *wheels
    ],
    check=True,
)

# 3. Copy repo and weights as usual
shutil.copytree(f"{ARTIFACTS}/repo", REPO_DIR, dirs_exist_ok=True)
shutil.copytree(f"{ARTIFACTS}/weights", f"{REPO_DIR}/weights", dirs_exist_ok=True)
sys.path.insert(0, f"{REPO_DIR}/src")
# Out:
# Looking in links: /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/imagecodecs-2026.6.26-cp312-abi3-manylinux_2_28_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/shellingham-1.5.4-py2.py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/numcodecs-0.15.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/bidict-0.23.1-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/requests-2.34.2-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/lazy_loader-0.5-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/typing_extensions-4.15.0-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/dask-2026.6.0-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/cloudpickle-3.1.2-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/toolz-1.1.0-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/pydantic_core-2.46.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/idna-3.18-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/imageio-2.37.3-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/psygnal-0.15.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/ndindex-1.10.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/tqdm-4.68.3-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/markdown_it_py-4.2.0-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/click-8.4.2-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/blosc2-4.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/zarr-3.2.1-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/certifi-2026.6.17-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/msgpack-1.2.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/partd-1.4.2-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/ilpy-0.6.0-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/urllib3-2.7.0-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/typing_inspection-0.4.2-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/networkx-3.6.1-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/annotated_types-0.7.0-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/annotated_doc-0.0.4-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/scikit_image-0.26.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/donfig-0.8.1.post1-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/wrapt-2.2.2-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/tracksdata-0.1.0rc6.dev3+g980c2d30a-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/threadpoolctl-3.6.0-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/pydantic-2.13.4-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/numexpr-2.14.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/tifffile-2026.6.1-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/typer-0.26.8-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/sqlalchemy-2.0.51-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/deprecated-1.3.1-py2.py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/fsspec-2026.6.0-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/google_crc32c-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/llvmlite-0.47.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/polars-1.42.0-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/geff-1.2.0.1.1-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/mdurl-0.1.2-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/numba-0.65.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/packaging-26.2-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/pygments-2.20.0-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/polars_runtime_32-1.42.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/pyscipopt-6.2.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/locket-1.0.0-py2.py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/rich-15.0.0-py3-none-any.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/greenlet-3.5.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl
# Processing /kaggle/input/datasets/thibautgoldsborough/cellmot-baseline-artifacts/cellmot-baseline-artifacts/wheels/geff_spec-1.1.1-py3-none-any.whl
# shellingham is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# lazy-loader is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# typing-extensions is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# charset-normalizer is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# cloudpickle is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# imageio is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# psygnal is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# ndindex is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# partd is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# typing-inspection is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# networkx is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# annotated-types is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# annotated-doc is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# threadpoolctl is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# numexpr is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# deprecated is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# google-crc32c is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# pyyaml is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# mdurl is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# pygments is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# locket is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# pyarrow is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Installing collected packages: zarr, wrapt, urllib3, typer, tracksdata, tqdm, toolz, tifffile, sqlalchemy, scipy, scikit-image, rustworkx, rich, requests, pyscipopt, pydantic-core, pydantic, polars-runtime-32, polars, pillow, packaging, numcodecs, numba, msgpack, markdown-it-py, llvmlite, imagecodecs, ilpy, idna, greenlet, geff-spec, geff, fsspec, donfig, dask, click, certifi, blosc2, bidict
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 2.1.2
#     Uninstalling wrapt-2.1.2:
#       Successfully uninstalled wrapt-2.1.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: typer
#     Found existing installation: typer 0.24.2
#     Uninstalling typer-0.24.2:
#       Successfully uninstalled typer-0.24.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.3
#     Uninstalling tqdm-4.67.3:
#       Successfully uninstalled tqdm-4.67.3
#   Attempting uninstall: toolz
#     Found existing installation: toolz 0.12.1
#     Uninstalling toolz-0.12.1:
#       Successfully uninstalled toolz-0.12.1
#   Attempting uninstall: tifffile
#     Found existing installation: tifffile 2026.4.11
#     Uninstalling tifffile-2026.4.11:
#       Successfully uninstalled tifffile-2026.4.11
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.49
#     Uninstalling SQLAlchemy-2.0.49:
#       Successfully uninstalled SQLAlchemy-2.0.49
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.25.2
#     Uninstalling scikit-image-0.25.2:
#       Successfully uninstalled scikit-image-0.25.2
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.41.4
#     Uninstalling pydantic_core-2.41.4:
#       Successfully uninstalled pydantic_core-2.41.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.12.3
#     Uninstalling pydantic-2.12.3:
#       Successfully uninstalled pydantic-2.12.3
#   Attempting uninstall: polars-runtime-32
#     Found existing installation: polars-runtime-32 1.35.2
#     Uninstalling polars-runtime-32-1.35.2:
#       Successfully uninstalled polars-runtime-32-1.35.2
#   Attempting uninstall: polars
#     Found existing installation: polars 1.35.2
#     Uninstalling polars-1.35.2:
#       Successfully uninstalled polars-1.35.2
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.1
#     Uninstalling packaging-26.1:
#       Successfully uninstalled packaging-26.1
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.1.2
#     Uninstalling msgpack-1.1.2:
#       Successfully uninstalled msgpack-1.1.2
#   Attempting uninstall: markdown-it-py
#     Found existing installation: markdown-it-py 4.0.0
#     Uninstalling markdown-it-py-4.0.0:
#       Successfully uninstalled markdown-it-py-4.0.0
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 3.4.0
#     Uninstalling greenlet-3.4.0:
#       Successfully uninstalled greenlet-3.4.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: dask
#     Found existing installation: dask 2026.1.1
#     Uninstalling dask-2026.1.1:
#       Successfully uninstalled dask-2026.1.1
#   Attempting uninstall: click
#     Found existing installation: click 8.3.3
#     Uninstalling click-8.3.3:
#       Successfully uninstalled click-8.3.3
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2026.4.22
#     Uninstalling certifi-2026.4.22:
#       Successfully uninstalled certifi-2026.4.22
#   Attempting uninstall: blosc2
#     Found existing installation: blosc2 4.1.2
#     Uninstalling blosc2-4.1.2:
#       Successfully uninstalled blosc2-4.1.2
# Successfully installed bidict-0.23.1 blosc2-4.7.0 certifi-2026.6.17 click-8.4.2 dask-2026.6.0 donfig-0.8.1.post1 fsspec-2026.6.0 geff-1.2.0.1.1 geff-spec-1.1.1 greenlet-3.5.3 idna-3.18 ilpy-0.6.0 imagecodecs-2026.6.26 llvmlite-0.47.0 markdown-it-py-4.2.0 msgpack-1.2.1 numba-0.65.1 numcodecs-0.15.1 packaging-26.2 pillow-12.2.0 polars-1.42.0 polars-runtime-32-1.42.0 pydantic-2.13.4 pydantic-core-2.46.4 pyscipopt-6.2.1 requests-2.34.2 rich-15.0.0 rustworkx-0.18.0 scikit-image-0.26.0 scipy-1.18.0 sqlalchemy-2.0.51 tifffile-2026.6.1 toolz-1.1.0 tqdm-4.68.3 tracksdata-0.1.0rc6.dev3+g980c2d30a typer-0.26.8 urllib3-2.7.0 wrapt-2.2.2 zarr-3.2.1

# %%
# import sys
# import shutil
# import subprocess

# subprocess.run(
#     ["pip", "install", "--no-index", "--find-links", f"{ARTIFACTS}/wheels", "--no-deps", "donfig",
#      "tracksdata", "zarr>=3.0.10", "pyscipopt"],
#     check=True)

# shutil.copytree(f"{ARTIFACTS}/repo", REPO_DIR, dirs_exist_ok=True)
# shutil.copytree(f"{ARTIFACTS}/weights", f"{REPO_DIR}/weights", dirs_exist_ok=True)
# sys.path.insert(0, f"{REPO_DIR}/src")

# print("Weights:", os.listdir(f"{REPO_DIR}/weights/{METHOD}/split_0"))

# %% [markdown]
# ## Inference on all test videos
# Build a one-fold splits file listing every test video, then run prediction. PYTHONPATH=src makes the tracking_cellmot package importable without an internet install. Each video's tracks are exported as a .geff graph.

# %%
import json

test_stems = sorted(f[:-5] for f in os.listdir(TEST_DIR) if f.endswith(".zarr"))
print(f"{len(test_stems)} test videos")
print(f"One element in test_stems is {test_stems[0]}")

with open(f"{REPO_DIR}/kaggle_test_splits.json", "w") as f:
    json.dump([{"split": 0, "train": [], "test": test_stems}], f)
# Out:
# 4 test videos
# One element in test_stems is 44b6_0113de3b

# %%
#---------- Reading back the json file just created ------------
with open(f"{REPO_DIR}/kaggle_test_splits.json", "r") as f:
    json_file = json.load(f)

json_file
# Out:
# [{'split': 0,
#   'train': [],
#   'test': ['44b6_0113de3b',
#    '44b6_0b24845f',
#    '6bba_05b6850b',
#    '6bba_05db0fb1']}]

# %%
import subprocess

# ----------------- command to run "predict_unet_transformer.py" which predicts data ------------------------
cmd = [
    "python", "scripts/predict_unet_transformer.py",
    "--data-dir", str(TEST_DIR), "--splits", "kaggle_test_splits.json", "--split", "0",
    "--weights", str(WEIGHTS), "--unet-batch-size", str(UNET_BATCH_SIZE),
    "--det-threshold", str(DET_THRESHOLD),
    "--ilp-edge-weight", str(ILP_EDGE_WEIGHT),
    "--ilp-appearance-weight", str(ILP_APPEARANCE_WEIGHT),
    "--ilp-disappearance-weight", str(ILP_DISAPPEARANCE_WEIGHT),
    "--ilp-division-weight", str(ILP_DIVISION_WEIGHT),
]
if USE_ILP:
    cmd.append("--use-ilp")
if SLICE:
    cmd += ["--slice", SLICE]

print(" ".join(cmd))
subprocess.run(cmd, cwd=REPO_DIR, env={**os.environ, "PYTHONPATH": "src"}, check=True)
# Out:
# python scripts/predict_unet_transformer.py --data-dir /kaggle/input/competitions/biohub-cell-tracking-during-development/test --splits kaggle_test_splits.json --split 0 --weights weights/unet_transformer/split_0/edge_predictor_best.pth --unet-batch-size 4 --det-threshold 0.99 --ilp-edge-weight -1.0 --ilp-appearance-weight 0.1 --ilp-disappearance-weight 0.1 --ilp-division-weight 1.0 --use-ilp --slice :4
# /usr/local/lib/python3.12/dist-packages/dask/array/image.py:7: FutureWarning: `find_available_plugins` is deprecated since version 0.25 and will be removed in version 0.27. The plugin infrastructure of `skimage.io` is deprecated. Instead, use `imageio` or other I/O packages directly.
#   from skimage.io import imread as sk_imread
# /usr/lib/python3.12/importlib/__init__.py:90: FutureWarning: `reset_plugins` is deprecated since version 0.25 and will be removed in version 0.27. The plugin infrastructure of `skimage.io` is deprecated. Instead, use `imageio` or other I/O packages directly.
#   return _bootstrap._gcd_import(name[level:], package, level)
# Fold 0: 4 datasets | weights=weights/unet_transformer/split_0/edge_predictor_best.pth | device=cuda | window_size=2 | pool_kernel_um=3.0
# Saved 4 predictions to /kaggle/working/repo/predictions/unknown/unet_transformer/split_0
# CompletedProcess(args=['python', 'scripts/predict_unet_transformer.py', '--data-dir', '/kaggle/input/competitions/biohub-cell-tracking-during-development/test', '--splits', 'kaggle_test_splits.json', '--split', '0', '--weights', 'weights/unet_transformer/split_0/edge_predictor_best.pth', '--unet-batch-size', '4', '--det-threshold', '0.99', '--ilp-edge-weight', '-1.0', '--ilp-appearance-weight', '0.1', '--ilp-disappearance-weight', '0.1', '--ilp-division-weight', '1.0', '--use-ilp', '--slice', ':4'], returncode=0)

# %% [markdown]
# # Build submission.csv
# Flatten the predicted .geff graphs into the competition's CSV format: one node row per detection (t, z, y, x) and one edge row per link (source_id, target_id)

# %%
from pathlib import Path

import pandas as pd
import tracksdata as td

geffs = sorted(Path(REPO_DIR, "predictions").glob(f"*/{METHOD}/split_0/*.geff"))
print(f"{len(geffs)} prediction graphs")

rows = []
for g in geffs:
    name = g.stem
    graph = td.graph.IndexedRXGraph.from_geff(g)
    graph = graph[0] if isinstance(graph, tuple) else graph
    for r in graph.node_attrs().iter_rows(named=True):
        rows.append({
            "dataset": name, "row_type": "node", "node_id": int(r["node_id"]),
            "t": int(r["t"]), "z": int(round(r["z"])), "y": int(round(r["y"])),
            "x": int(round(r["x"])), "source_id": -1, "target_id": -1,
        })
    for r in graph.edge_attrs().iter_rows(named=True):
        rows.append({
            "dataset": name, "row_type": "edge", "node_id": -1,
            "t": -1, "z": -1, "y": -1, "x": -1,
            "source_id": int(r["source_id"]), "target_id": int(r["target_id"]),
        })

submission = pd.DataFrame(
    rows,
    columns=["dataset", "row_type", "node_id", "t", "z", "y", "x", "source_id", "target_id"],
)
submission.index.name = "id"
submission.to_csv("submission.csv")
print(f"Wrote submission.csv with {len(submission)} rows")
submission.head()
# Out:
# /usr/local/lib/python3.12/dist-packages/dask/array/image.py:7: FutureWarning: `find_available_plugins` is deprecated since version 0.25 and will be removed in version 0.27. The plugin infrastructure of `skimage.io` is deprecated. Instead, use `imageio` or other I/O packages directly.
#   from skimage.io import imread as sk_imread
# /usr/lib/python3.12/importlib/__init__.py:90: FutureWarning: `reset_plugins` is deprecated since version 0.25 and will be removed in version 0.27. The plugin infrastructure of `skimage.io` is deprecated. Instead, use `imageio` or other I/O packages directly.
#   return _bootstrap._gcd_import(name[level:], package, level)
# 4 prediction graphs
# Wrote submission.csv with 304792 rows
#           dataset row_type  node_id  t  z    y   x  source_id  target_id
# id
# 0   44b6_0113de3b     node        0  0  1    8  52         -1         -1
# 1   44b6_0113de3b     node        1  0  1    8  72         -1         -1
# 2   44b6_0113de3b     node        2  0  1   24  64         -1         -1
# 3   44b6_0113de3b     node        3  0  1   64  60         -1         -1
# 4   44b6_0113de3b     node        4  0  1  100  36         -1         -1

# %%
# import numpy as np
# import pandas as pd

# %%
# sample_sub = pd.read_csv('/kaggle/input/competitions/biohub-cell-tracking-during-development/sample_submission.csv')
# sample_sub

# %%
# submission_full = pd.read_csv("submission.csv")
# submission_full.head(20)

# %%
# sub = submission_full  # your full 4-dataset file

# print("="*60)
# print("A. UNEXPECTED VALUES / WHITESPACE")
# print("="*60)
# print("row_type values:", sub['row_type'].unique())
# print("dataset values match sample exactly?")
# print(sorted(sub['dataset'].unique()))
# print(sorted(sample['dataset'].unique()))
# # catch hidden whitespace
# print(sub['dataset'].apply(lambda s: s != s.strip()).sum(), "dataset values with stray whitespace")

# print("\n" + "="*60)
# print("B. SELF-LOOP / DEGENERATE EDGES")
# print("="*60)
# edges = sub[sub['row_type']=='edge']
# self_loops = edges[edges['source_id'] == edges['target_id']]
# print("self-loop edges (source_id == target_id):", len(self_loops))

# print("\n" + "="*60)
# print("C. DUPLICATE EDGES")
# print("="*60)
# dupe_edges = edges[edges.duplicated(subset=['dataset','source_id','target_id'], keep=False)]
# print("duplicate (dataset,source_id,target_id) edges:", len(dupe_edges))

# print("\n" + "="*60)
# print("D. TEMPORAL ORDERING OF EDGES (must go forward in time)")
# print("="*60)
# nodes = sub[sub['row_type']=='node']
# node_t = nodes.set_index(['dataset','node_id'])['t']
# bad_dir = 0
# for ds, grp in edges.groupby('dataset'):
#     t_src = grp.apply(lambda r: node_t.get((ds, r['source_id']), None), axis=1)
#     t_tgt = grp.apply(lambda r: node_t.get((ds, r['target_id']), None), axis=1)
#     bad = grp[(t_tgt.values <= t_src.values)]
#     if len(bad):
#         bad_dir += len(bad)
#         print(f"!! {ds}: {len(bad)} edges where target t <= source t")
# print("total bad-direction edges:", bad_dir)

# print("\n" + "="*60)
# print("E. MULTIPLE PARENTS (tree constraint — each node at most 1 incoming edge)")
# print("="*60)
# parent_counts = edges.groupby(['dataset','target_id']).size()
# multi_parent = parent_counts[parent_counts > 1]
# print("nodes with >1 incoming edge:", len(multi_parent))
# if len(multi_parent):
#     print(multi_parent.head(10))

# print("\n" + "="*60)
# print("F. FILE SIZE")
# print("="*60)
# import os
# # adjust path to your actual submitted file
# path = 'submission.csv'  # change if needed
# if os.path.exists(path):
#     print(f"{os.path.getsize(path)/1e6:.2f} MB")
# else:
#     print("point this at your actual submitted csv path")
